# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup
url = 'http://isee.scu.edu.tw/'
# 利用Cookies/Session 登入
# 觀察瀏覽器記錄的資訊是什什麼，將 cookie 帶在請求當中
# F12 -> Application -> Cookies - > MoodleSession的值在登入後改變
response = requests.get(url, verify = False, cookies = {'MoodleSession':'792d012ef43e980d12de6a0bb3244176'})
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" dir="ltr" lang="zh-tw" xml:lang="zh-tw">
# <head>
# <title>東吳大學Moodle數位平台</title>
# <link href="http://isee.scu.edu.tw/theme/image.php/essential/theme/1571206476/favicon" rel="shortcut icon"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="moodle, 東吳大學Moodle數位平台" name="keywords"/>
# <link href="http://isee.scu.edu.tw/theme/yui_combo.php?rollup/3.17.2/yui-moodlesimple-min.css" rel="stylesheet" type="text/css"/><script id="firstthemesheet" type="text/css">/** Required in order to fix style inclusion problems in IE with YUI **/</script><link href="http://isee.scu.edu.tw/theme/styles.php/essential/1571206476_1/all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# //<![CDATA[
# var M = {}; M.yui = {};
# M.pageloadstarttime = new Date();
# ...
